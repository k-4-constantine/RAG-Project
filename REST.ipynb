# %% [markdown]
# # REST

# %% [markdown]
# ## Consuming APIs

# %% [markdown]
# Get

# %%
import requests
api_url = "https://jsonplaceholder.typicode.com/todos/1"
response = requests.get(api_url)
response.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# Post

# %%
api_url = "https://jsonplaceholder.typicode.com/todos"
todo = {"userId": 1, "title": "Buy milk", "completed": False}
response = requests.post(api_url, json=todo)
response.json()
# Out:
# {'userId': 1, 'title': 'Buy milk', 'completed': False, 'id': 201}

# %% [markdown]
# Put

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
response = requests.get(api_url)
response.json()
# Out:
# {'userId': 1,
#  'id': 10,
#  'title': 'illo est ratione doloremque quia maiores aut',
#  'completed': True}

# %%
todo = {"userId": 1, "title": "Wash car", "completed": True}
response = requests.put(api_url, json=todo)
response.json()
# Out:
# {'userId': 1, 'title': 'Wash car', 'completed': True, 'id': 10}

# %% [markdown]
# response.status_code = 200, since it's a replacement

# %% [markdown]
# Patch

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
todo = {"title": "Mow lawn"}
response = requests.patch(api_url, json=todo)
response.json()
# Out:
# {'userId': 1, 'id': 10, 'title': 'Mow lawn', 'completed': True}

# %% [markdown]
# Partial change

# %% [markdown]
# Delete

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
response = requests.delete(api_url)
response.json()
# Out:
# {}

# %% [markdown]
# # Project

# %%
import requests
api_url = "https://pokeapi.co/api/v2/pokemon/ditto"
response = requests.get(api_url)
response.json()
# Out:
# {'abilities': [{'ability': {'name': 'limber',
#     'url': 'https://pokeapi.co/api/v2/ability/7/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'imposter',
#     'url': 'https://pokeapi.co/api/v2/ability/150/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 101,
#  'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/132.ogg',
#   'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/132.ogg'},
#  'forms': [{'name': 'ditto',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/132/'}],
#  'game_indices': [{'game_index': 76,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 76,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 76,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 132,
# ...

# %%
import requests

# 获取用户信息
username = "k-4-constantine"
url = f"https://api.github.com/users/{username}"

response = requests.get(url)

# 检查状态码
print(response.status_code)

# 打印 JSON 数据
data = response.json()
print(data)
# Out:
# 403
# {'message': "API rate limit exceeded for 20.61.127.48. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", 'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}

# %%
token = "token"  # ⚠️ 不要公开
headers = {"Authorization": f"token {token}"}

url = "https://api.github.com/user"
response = requests.get(url, headers=headers)

print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
url = "https://api.github.com/user/repos"
response = requests.get(url, headers=headers)
repos = response.json()

for repo in repos:
    print(repo["name"], repo["html_url"])
# Out:
# ML_assignments https://github.com/CrownCrafter/ML_assignments
# PTS2-Assignments https://github.com/CrownCrafter/PTS2-Assignments
# Locke-Truth https://github.com/k-4-constantine/Locke-Truth
# MLOps-zoomcamp https://github.com/k-4-constantine/MLOps-zoomcamp
# ML_assignments https://github.com/k-4-constantine/ML_assignments
# personal_website.github.io https://github.com/k-4-constantine/personal_website.github.io
# RAG-Project https://github.com/k-4-constantine/RAG-Project
# Semantic_Artwork_Understanding https://github.com/k-4-constantine/Semantic_Artwork_Understanding

# %%
url = "https://api.github.com/repos/k-4-constantine/MLOps-zoomcamp/commits"
commits = requests.get(url, headers=headers).json()

for c in commits[:5]:
    print(c["commit"]["message"], "-", c["commit"]["author"]["name"])
# Out:
# week 3 - k-4-constantine
# 2.5 - k-4-constantine
# 2.4 - k-4-constantine
# update homework2 - k-4-constantine
# add requirements.txt for experiment tracking - k-4-constantine

# %%
url = "https://api.github.com/user/repos"
response = requests.get(url, headers=headers)
repos = response.json()

most_forked = max(repos, key=lambda r: r["forks_count"])
most_forked['name']
# Out:
# 'ML_assignments'

# %%
username = "andrewyng"
url = f"https://api.github.com/users/{username}/repos"

response = requests.get(url, headers=headers)
repos = response.json()

top_forks = sorted(repos, key=lambda r: r["forks_count"], reverse=True)[:3]

print(f"用户 {username} 的 fork 数最多的前三个仓库：")
for repo in top_forks:
    print(f"{repo['name']} - {repo['forks_count']} forks - {repo['html_url']}")
# Out:
# 用户 andrewyng 的 fork 数最多的前三个仓库：
# aisuite - 1265 forks - https://github.com/andrewyng/aisuite
# translation-agent - 688 forks - https://github.com/andrewyng/translation-agent
# audio - 6 forks - https://github.com/andrewyng/audio
